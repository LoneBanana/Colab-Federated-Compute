# %%
#Testing writing linux commands in python:

import subprocess as sp

res = sp.run("ls -l".split(" "), capture_output=True)

print(res.stdout.strip().decode("utf-8")) #decode("utf-8") is used for making byte-string into regular string


#if you want to read it as byte-code

# res2 = sp.run("ls -l".split(" "), capture_output=True, text=False)

# print(res2.stdout)
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 sample_data
# b'total 4\ndrwxr-xr-x 1 root root 4096 Jun  4 13:32 sample_data\n'

# %%
#Goal #1: temp1.ipynb should be able to take some linux commands as input and then put them into a file buffer
# -- Output should be the ability of temp2.ipynb to receive the command and perform instructions accordingly



flag = False

cmd = r"cd ..; ls -ltr; cd.."

from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive

gauth = GoogleAuth.LocalWebserverAuth()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_790/1084845106.py in <cell line: 0>()
#       5 from pydrive2.drive import GoogleDrive
#       6
# ----> 7 gauth = GoogleAuth.LocalWebserverAuth()
#       8
#
# TypeError: _PyDrive2ImportHook.find_spec.<locals>.init_code_callback.<locals>.PatchedLocalWebServerAuth() missing 1 required positional argument: 'self'
