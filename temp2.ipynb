# %% [markdown]
# <a href="https://colab.research.google.com/github/LoneBanana/Colab-Federated-Compute/blob/main/temp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
DIRPATH = r"/content/drive/MyDrive/Colab Notebooks/Colab-Federated-Compute-Model"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
buf_out = []

with open(f"{DIRPATH}/temp_f.md", "r") as f:
  for line in f: #Reason you can perform this operation is because for-in by default catches StopIteration
    buf_out.append(line)

print(buf_out)
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/Colab-Federated-Compute-Model\n', 'ls -ltr;']

# %%
import subprocess as sp

res = sp.run(buf_out[1], capture_output=True, shell=True)
res_txt = res.stdout.decode('utf-8')
print(res_txt)
# Out:
# total 8
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 sample_data
# drwx------ 5 root root 4096 Jun 25 22:58 drive
